# %%
import pandas as pd

# %%
input_cluster = 'https://github.com/Kinrider/tech_challenge_5/raw/refs/heads/main/01_fontes/arquivos_decision/fontes_tratadas/02_candidatos_tratados.parquet'

df = pd.read_parquet(input_cluster)

# %%
df.head()
# Out:
#   id_candidato    data_atualizacao        data_criacao  meses_desde_criacao  \
# 0        31000 2021-10-11 07:29:49 2021-10-11 07:29:49                 45.0
# 1        31001 2021-11-11 11:10:31 2021-10-11 08:56:16                 45.0
# 2        31002 2021-10-11 11:42:36 2021-10-11 09:01:00                 45.0
# 3        31003 2021-10-11 16:04:51 2021-10-11 09:08:13                 45.0
# 4        31004 2021-10-11 09:22:03 2021-10-11 09:18:46                 45.0
#
#    meses_desde_atualizacao faixa_criacao faixa_atualizacao remuneracao  \
# 0                     45.0       +3 anos           +3 anos
# 1                     44.0       +3 anos           +3 anos        1900
# 2                     45.0       +3 anos           +3 anos    2.500,00
# 3                     45.0       +3 anos           +3 anos     1100,00
# 4                     45.0       +3 anos           +3 anos
#
#    remuneracao_mensal_brl  remuneracao_zscore faixa_remuneracao  \
# ...

# %%
df_filtrado = df[["remuneracao_mensal_brl"]]

# %%
Caminho = "C:\\Users\\pedro\\Documents\\Área de Trabalho\\tech_challenge_5\\01_fontes\\arquivos_decision\\fontes_tratadas\\"

df_filtrado.to_parquet(Caminho + "remuneracao_mensal_only.parquet", index=False)
